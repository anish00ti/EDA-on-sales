# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load your dataset
df = pd.read_csv("../data/raw/new_sales.csv")

# Generate profiling report
profile = ProfileReport(df, title="Sales Report", explorative=True)

# Save as HTML file
profile.to_file("report.html")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 from ydata_profiling import ProfileReport
#       4 # Load your dataset
# ----> 5 df = pd.read_csv("EDA-on-sales/data/raw/new_sales.csv")
#       7 # Generate profiling report
#       8 profile = ProfileReport(df, title="Sales Report", explorative=True)
#
# ...

# %%
# Out:
# ...
#   Using cached ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# ...
#   Using cached phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# ...
# Using cached ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# Using cached phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# ...
#
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
#    ---------------------------------------- 0/3 [pydantic]
# ...
